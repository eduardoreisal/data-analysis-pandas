# %%
import pandas as pd
houses = pd.read_csv('DataAnalysis/data/kc_house_data.csv')
titanic = pd.read_csv('DataAnalysis/data/titanic.csv')
netflix = pd.read_csv('DataAnalysis/data/netflix_titles.csv', sep="|", index_col=0)
bitcoin = pd.read_csv('DataAnalysis/data/coin_Bitcoin.csv')
countries = pd.read_csv('DataAnalysis/data/world-happiness-report-2021.csv')

# %%
bitcoin.drop(labels=["SNo", "Name", "Symbol"], axis='columns')
# Out:
#                      Date          High           Low          Open  \
# 0     2013-04-29 23:59:59    147.488007    134.000000    134.444000
# 1     2013-04-30 23:59:59    146.929993    134.050003    144.000000
# 2     2013-05-01 23:59:59    139.889999    107.720001    139.000000
# 3     2013-05-02 23:59:59    125.599998     92.281898    116.379997
# 4     2013-05-03 23:59:59    108.127998     79.099998    106.250000
# ...                   ...           ...           ...           ...
# 2986  2021-07-02 23:59:59  33939.588699  32770.680780  33549.600177
# 2987  2021-07-03 23:59:59  34909.259899  33402.696536  33854.421362
# 2988  2021-07-04 23:59:59  35937.567147  34396.477458  34665.564866
# 2989  2021-07-05 23:59:59  35284.344430  33213.661034  35284.344430
# 2990  2021-07-06 23:59:59  35038.536363  33599.916169  33723.509655
#
#              Close        Volume     Marketcap
# 0       144.539993  0.000000e+00  1.603769e+09
# 1       139.000000  0.000000e+00  1.542813e+09
# ...

# %%
bitcoin.drop(columns=["SNo", "Name", "Symbol"])
# Out:
#                      Date          High           Low          Open  \
# 0     2013-04-29 23:59:59    147.488007    134.000000    134.444000
# 1     2013-04-30 23:59:59    146.929993    134.050003    144.000000
# 2     2013-05-01 23:59:59    139.889999    107.720001    139.000000
# 3     2013-05-02 23:59:59    125.599998     92.281898    116.379997
# 4     2013-05-03 23:59:59    108.127998     79.099998    106.250000
# ...                   ...           ...           ...           ...
# 2986  2021-07-02 23:59:59  33939.588699  32770.680780  33549.600177
# 2987  2021-07-03 23:59:59  34909.259899  33402.696536  33854.421362
# 2988  2021-07-04 23:59:59  35937.567147  34396.477458  34665.564866
# 2989  2021-07-05 23:59:59  35284.344430  33213.661034  35284.344430
# 2990  2021-07-06 23:59:59  35038.536363  33599.916169  33723.509655
#
#              Close        Volume     Marketcap
# 0       144.539993  0.000000e+00  1.603769e+09
# 1       139.000000  0.000000e+00  1.542813e+09
# ...

# %%
bitcoin[["Date", "High", "Low"]]
# Out:
#                      Date          High           Low
# 0     2013-04-29 23:59:59    147.488007    134.000000
# 1     2013-04-30 23:59:59    146.929993    134.050003
# 2     2013-05-01 23:59:59    139.889999    107.720001
# 3     2013-05-02 23:59:59    125.599998     92.281898
# 4     2013-05-03 23:59:59    108.127998     79.099998
# ...                   ...           ...           ...
# 2986  2021-07-02 23:59:59  33939.588699  32770.680780
# 2987  2021-07-03 23:59:59  34909.259899  33402.696536
# 2988  2021-07-04 23:59:59  35937.567147  34396.477458
# 2989  2021-07-05 23:59:59  35284.344430  33213.661034
# 2990  2021-07-06 23:59:59  35038.536363  33599.916169
#
# [2991 rows x 3 columns]

# %%
countries.drop(['Denmark', 'Iceland', 'Finland'], axis=0)
# Out:
#               Regional indicator  Ladder score  \
# Country name
# Switzerland       Western Europe         7.571
# Netherlands       Western Europe         7.464
# Norway            Western Europe         7.392
# Sweden            Western Europe         7.363
# Luxembourg        Western Europe         7.324
# ...                          ...           ...
# Lesotho       Sub-Saharan Africa         3.512
# Botswana      Sub-Saharan Africa         3.467
# Rwanda        Sub-Saharan Africa         3.415
# Zimbabwe      Sub-Saharan Africa         3.145
# Afghanistan           South Asia         2.523
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Switzerland                            0.036         7.643         7.500
# Netherlands                            0.027         7.518         7.410
# Norway                                 0.035         7.462         7.323
# ...

# %%
bitcoin.sort_index(ascending=False, inplace=True)
bitcoin.drop(['SNo', 'Name', 'Symbol', 'Open', 'Close'], axis=1)
bitcoin.drop([2990, 2987, 1], axis=0)
# Out:
#        SNo     Name Symbol                 Date          High           Low  \
# 2989  2990  Bitcoin    BTC  2021-07-05 23:59:59  35284.344430  33213.661034
# 2988  2989  Bitcoin    BTC  2021-07-04 23:59:59  35937.567147  34396.477458
# 2986  2987  Bitcoin    BTC  2021-07-02 23:59:59  33939.588699  32770.680780
# 2985  2986  Bitcoin    BTC  2021-07-01 23:59:59  35035.982712  32883.781226
# 2984  2985  Bitcoin    BTC  2021-06-30 23:59:59  36074.759757  34086.151878
# ...    ...      ...    ...                  ...           ...           ...
# 5        6  Bitcoin    BTC  2013-05-04 23:59:59    115.000000     92.500000
# 4        5  Bitcoin    BTC  2013-05-03 23:59:59    108.127998     79.099998
# 3        4  Bitcoin    BTC  2013-05-02 23:59:59    125.599998     92.281898
# 2        3  Bitcoin    BTC  2013-05-01 23:59:59    139.889999    107.720001
# 0        1  Bitcoin    BTC  2013-04-29 23:59:59    147.488007    134.000000
#
# ...

# %%
countries.drop(countries.index[1:11])
# Out:
#                         Regional indicator  Ladder score  \
# Country name
# Finland                     Western Europe         7.842
# Israel        Middle East and North Africa         7.157
# Germany                     Western Europe         7.155
# Canada               North America and ANZ         7.103
# Ireland                     Western Europe         7.085
# ...                                    ...           ...
# Lesotho                 Sub-Saharan Africa         3.512
# Botswana                Sub-Saharan Africa         3.467
# Rwanda                  Sub-Saharan Africa         3.415
# Zimbabwe                Sub-Saharan Africa         3.145
# Afghanistan                     South Asia         2.523
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Finland                                0.032         7.904         7.780
# Israel                                 0.034         7.224         7.090
# ...

# %%
titanic["species"] = 'human'
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex     age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
houses.insert(0, 'county', "King County")
houses
# Out:
#             county        count          id             date     price  \
# 0      King County  King County  7129300520  20141013T000000  221900.0
# 1      King County  King County  6414100192  20141209T000000  538000.0
# 2      King County  King County  5631500400  20150225T000000  180000.0
# 3      King County  King County  2487200875  20141209T000000  604000.0
# 4      King County  King County  1954400510  20150218T000000  510000.0
# ...            ...          ...         ...              ...       ...
# 21608  King County  King County   263000018  20140521T000000  360000.0
# 21609  King County  King County  6600060120  20150223T000000  400000.0
# 21610  King County  King County  1523300141  20140623T000000  402101.0
# 21611  King County  King County   291310100  20150116T000000  400000.0
# 21612  King County  King County  1523300157  20141015T000000  325000.0
#
#        bedrooms  bathrooms  sqft_living  sqft_lot  floors  ...  grade  \
# ...

# %%
houses['sale_price'] = houses['price']
houses
# Out:
#             county        count          id             date     price  \
# 0      King County  King County  7129300520  20141013T000000  221900.0
# 1      King County  King County  6414100192  20141209T000000  538000.0
# 2      King County  King County  5631500400  20150225T000000  180000.0
# 3      King County  King County  2487200875  20141209T000000  604000.0
# 4      King County  King County  1954400510  20150218T000000  510000.0
# ...            ...          ...         ...              ...       ...
# 21608  King County  King County   263000018  20140521T000000  360000.0
# 21609  King County  King County  6600060120  20150223T000000  400000.0
# 21610  King County  King County  1523300141  20140623T000000  402101.0
# 21611  King County  King County   291310100  20150116T000000  400000.0
# 21612  King County  King County  1523300157  20141015T000000  325000.0
#
#        bedrooms  bathrooms  sqft_living  sqft_lot  floors  ...  sqft_above  \
# ...

# %%
houses.insert(3, 'num_bedrooms', houses['bedrooms'])
houses
# Out:
#             county        count          id  num_bedrooms             date  \
# 0      King County  King County  7129300520             3  20141013T000000
# 1      King County  King County  6414100192             3  20141209T000000
# 2      King County  King County  5631500400             2  20150225T000000
# 3      King County  King County  2487200875             4  20141209T000000
# 4      King County  King County  1954400510             3  20150218T000000
# ...            ...          ...         ...           ...              ...
# 21608  King County  King County   263000018             3  20140521T000000
# 21609  King County  King County  6600060120             4  20150223T000000
# 21610  King County  King County  1523300141             2  20140623T000000
# 21611  King County  King County   291310100             3  20150116T000000
# 21612  King County  King County  1523300157             2  20141015T000000
#
# ...

# %%
titanic['num relatives'] = titanic['sibsp'] + titanic['parch']
titanic.sort_values('num relatives', ascending=False)
titanic['num relatives'].value_counts()
# Out:
# 0     790
# 1     235
# 2     159
# 3      43
# 5      25
# 4      22
# 6      16
# 10     11
# 7       8
# Name: num relatives, dtype: int64

# %%
titanic[(titanic['survived'] == 1) & (titanic['num relatives'] > 0)]['num relatives'].value_counts().plot(kind='pie')
# Out:
# <AxesSubplot: ylabel='num relatives'>

# %%
single_female = titanic[(titanic['num relatives'] == 0) & (titanic['sex'] == 'female')].sort_values('age')
single_female = single_female[pd.to_numeric(single_female['age'], errors='coerce').notnull()]
single_female
# Out:
#       pclass  survived                                             name  \
# 582        2         1                             Watt, Miss. Bertha J
# 653        3         1                             Ayoub, Miss. Banoura
# 1279       3         0             Vestrom, Miss. Hulda Amanda Adolfina
# 1007       3         1                      McGowan, Miss. Anna 'Annie'
# 1047       3         1                 Najib, Miss. Adele Kiamie 'Jane'
# ...      ...       ...                                              ...
# 192        1         1                             Lurette, Miss. Elise
# 33         1         1                         Bonnell, Miss. Elizabeth
# 43         1         1  Bucknell, Mrs. William Robert (Emma Eliza Ward)
# 284        1         1        Stone, Mrs. George Nelson (Martha Evelyn)
# 1261       3         1                           Turkula, Mrs. (Hedwig)
#
#          sex age  sibsp  parch      ticket      fare cabin embarked boat body  \
# ...

# %%
houses['price sqtr'] = houses['price'] / houses['sqft_lot']
houses.sort_values('price sqtr')
# Out:
#             county        count          id  num_bedrooms             date  \
# 17319  King County  King County  3326079016             2  20150504T000000
# 1719   King County  King County  1020069017             4  20150327T000000
# 7647   King County  King County  2623069031             5  20140521T000000
# 2757   King County  King County  3520069033             3  20140623T000000
# 4540   King County  King County  2522029039             3  20140929T000000
# ...            ...          ...         ...           ...              ...
# 20567  King County  King County  6926700654             2  20140921T000000
# 15679  King County  King County  5026900235             4  20140911T000000
# 18010  King County  King County  7234601198             3  20140604T000000
# 15743  King County  King County  9828702895             4  20141022T000000
# 3452   King County  King County  2559950110             2  20150422T000000
#
#            price  bedrooms  bathrooms  sqft_living  sqft_lot  ...  \
# ...

# %%
bitcoin.set_index('Date')
bitcoin['Difference'] = bitcoin['Close'] - bitcoin['Open']
bitcoin.sort_values('Difference', ascending=False).head(10)
bitcoin.set_index('Date').sort_values('Difference', ascending=False).head(10)['Difference'].plot(kind='bar')
# Out:
# <AxesSubplot: xlabel='Date'>
