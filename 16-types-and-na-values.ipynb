# %%
import pandas as pd
houses = pd.read_csv('DataAnalysis/data/kc_house_data.csv')
titanic = pd.read_csv('DataAnalysis/data/titanic.csv')
netflix = pd.read_csv('DataAnalysis/data/netflix_titles.csv', sep="|", index_col=0)
bitcoin = pd.read_csv('DataAnalysis/data/coin_Bitcoin.csv')
countries = pd.read_csv('DataAnalysis/data/world-happiness-report-2021.csv')

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1309 non-null   object
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1309 non-null   object
#  9   cabin      1309 non-null   object
#  10  embarked   1309 non-null   object
#  11  boat       1309 non-null   object
#  12  body       1309 non-null   object
#  13  home.dest  1309 non-null   object
# dtypes: int64(4), object(10)
# memory usage: 143.3+ KB

# %%
titanic['age'].value_counts()
# Out:
# ?         263
# 24         47
# 22         43
# 21         41
# 30         40
#          ...
# 66          1
# 0.6667      1
# 76          1
# 67          1
# 26.5        1
# Name: age, Length: 99, dtype: int64

# %%
titanic['age'].replace(['?'], [None], inplace=True)

# %%
titanic.age.value_counts(dropna=False)
# Out:
# None      263
# 24         47
# 22         43
# 21         41
# 30         40
#          ...
# 66          1
# 0.6667      1
# 76          1
# 67          1
# 26.5        1
# Name: age, Length: 99, dtype: int64

# %%
titanic['age_float'] = titanic['age'].astype('float')
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# 0     female  29.0000      0      0   24160  211.3375       B5        S    2
# 1       male   0.9167      1      2  113781    151.55  C22 C26        S   11
# 2     female   2.0000      1      2  113781    151.55  C22 C26        S    ?
# 3       male  30.0000      1      2  113781    151.55  C22 C26        S    ?
# 4     female  25.0000      1      2  113781    151.55  C22 C26        S    ?
# ...      ...      ...    ...    ...     ...       ...      ...      ...  ...
# 1304  female  14.5000      1      0    2665   14.4542        ?        C    ?
# 1305  female      NaN      1      0    2665   14.4542        ?        C    ?
# 1306    male  26.5000      0      0    2656     7.225        ?        C    ?
# 1307    male  27.0000      0      0    2670     7.225        ?        C    ?
# 1308    male  29.0000      0      0  315082     7.875        ?        S    ?
#
#      body                        home.dest  age_float
# 0       ?                     St Louis, MO    29.0000
# 1       ?  Montreal, PQ / Chesterville, ON     0.9167
# 2       ?  Montreal, PQ / Chesterville, ON     2.0000
# 3     135  Montreal, PQ / Chesterville, ON    30.0000
# 4       ?  Montreal, PQ / Chesterville, ON    25.0000
# ...   ...                              ...        ...
# 1304  328                                ?    14.5000
# 1305    ?                                ?        NaN
# 1306  304                                ?    26.5000
# 1307    ?                                ?    27.0000
# 1308    ?                                ?    29.0000
#
# [1309 rows x 15 columns]

# %%
titanic['age'] = titanic['age'].astype('float')
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# 0     female  29.0000      0      0   24160  211.3375       B5        S    2
# 1       male   0.9167      1      2  113781    151.55  C22 C26        S   11
# 2     female   2.0000      1      2  113781    151.55  C22 C26        S    ?
# 3       male  30.0000      1      2  113781    151.55  C22 C26        S    ?
# 4     female  25.0000      1      2  113781    151.55  C22 C26        S    ?
# ...      ...      ...    ...    ...     ...       ...      ...      ...  ...
# 1304  female  14.5000      1      0    2665   14.4542        ?        C    ?
# 1305  female      NaN      1      0    2665   14.4542        ?        C    ?
# 1306    male  26.5000      0      0    2656     7.225        ?        C    ?
# 1307    male  27.0000      0      0    2670     7.225        ?        C    ?
# 1308    male  29.0000      0      0  315082     7.875        ?        S    ?
#
#      body                        home.dest  age_float
# 0       ?                     St Louis, MO    29.0000
# 1       ?  Montreal, PQ / Chesterville, ON     0.9167
# 2       ?  Montreal, PQ / Chesterville, ON     2.0000
# 3     135  Montreal, PQ / Chesterville, ON    30.0000
# 4       ?  Montreal, PQ / Chesterville, ON    25.0000
# ...   ...                              ...        ...
# 1304  328                                ?    14.5000
# 1305    ?                                ?        NaN
# 1306  304                                ?    26.5000
# 1307    ?                                ?    27.0000
# 1308    ?                                ?    29.0000
#
# [1309 rows x 15 columns]

# %%
male = titanic['sex'] == 'male'
titanic[male]['age'].mean()
# Out:
# 30.5852329787234

# %%
female = titanic['sex'] == 'female'
titanic[female]['age'].mean()
# Out:
# 28.6870706185567

# %%
category = titanic['sex'].astype('category')
titanic['sex'] = category
titanic['sex']
# Out:
# 0       female
# 1         male
# 2       female
# 3         male
# 4       female
#          ...
# 1304    female
# 1305    female
# 1306      male
# 1307      male
# 1308      male
# Name: sex, Length: 1309, dtype: category
# Categories (2, object): ['female', 'male']

# %%
titanic['embarked'] = titanic['embarked'].astype('category')
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 15 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   category
#  4   age        1046 non-null   float64
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1309 non-null   object
#  9   cabin      1309 non-null   object
#  10  embarked   1309 non-null   category
#  11  boat       1309 non-null   object
#  12  body       1309 non-null   object
#  13  home.dest  1309 non-null   object
#  14  age_float  1046 non-null   float64
# dtypes: category(2), float64(2), int64(4), object(7)
# memory usage: 135.9+ KB

# %%
titanic['age'].value_counts()
# Out:
# 24.0000    47
# 22.0000    43
# 21.0000    41
# 30.0000    40
# 18.0000    39
#            ..
# 0.3333      1
# 22.5000     1
# 70.5000     1
# 0.6667      1
# 26.5000     1
# Name: age, Length: 98, dtype: int64

# %%
titanic['age'] = pd.to_numeric(titanic['age'], errors="coerce")
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# 0     female  29.0000      0      0   24160  211.3375       B5        S    2
# 1       male   0.9167      1      2  113781    151.55  C22 C26        S   11
# 2     female   2.0000      1      2  113781    151.55  C22 C26        S    ?
# 3       male  30.0000      1      2  113781    151.55  C22 C26        S    ?
# 4     female  25.0000      1      2  113781    151.55  C22 C26        S    ?
# ...      ...      ...    ...    ...     ...       ...      ...      ...  ...
# 1304  female  14.5000      1      0    2665   14.4542        ?        C    ?
# 1305  female      NaN      1      0    2665   14.4542        ?        C    ?
# 1306    male  26.5000      0      0    2656     7.225        ?        C    ?
# 1307    male  27.0000      0      0    2670     7.225        ?        C    ?
# 1308    male  29.0000      0      0  315082     7.875        ?        S    ?
#
#      body                        home.dest  age_float
# 0       ?                     St Louis, MO    29.0000
# 1       ?  Montreal, PQ / Chesterville, ON     0.9167
# 2       ?  Montreal, PQ / Chesterville, ON     2.0000
# 3     135  Montreal, PQ / Chesterville, ON    30.0000
# 4       ?  Montreal, PQ / Chesterville, ON    25.0000
# ...   ...                              ...        ...
# 1304  328                                ?    14.5000
# 1305    ?                                ?        NaN
# 1306  304                                ?    26.5000
# 1307    ?                                ?    27.0000
# 1308    ?                                ?    29.0000
#
# [1309 rows x 15 columns]

# %%
titanic['age'].describe()
# Out:
# count    1046.000000
# mean       29.881135
# std        14.413500
# min         0.166700
# 25%        21.000000
# 50%        28.000000
# 75%        39.000000
# max        80.000000
# Name: age, dtype: float64

# %%
titanic[titanic['age'].isna()]
# Out:
#       pclass  survived                                               name  \
# 15         1         0                                Baumann, Mr. John D
# 37         1         1      Bradley, Mr. George ('George Arthur Brayton')
# 40         1         0                          Brewe, Dr. Arthur Jackson
# 46         1         0                              Cairns, Mr. Alexander
# 59         1         1  Cassebeer, Mrs. Henry Arthur Jr (Eleanor Genev...
# ...      ...       ...                                                ...
# 1293       3         0                  Williams, Mr. Howard Hugh 'Harry'
# 1297       3         0                             Wiseman, Mr. Phillippe
# 1302       3         0                                  Yousif, Mr. Wazli
# 1303       3         0                              Yousseff, Mr. Gerious
# 1305       3         0                              Zabour, Miss. Thamine
#
#          sex  age  sibsp  parch      ticket     fare cabin embarked boat body  \
# 15      male  NaN      0      0    PC 17318   25.925     ?        S    ?    ?
# 37      male  NaN      0      0      111427    26.55     ?        S    9    ?
# 40      male  NaN      0      0      112379     39.6     ?        C    ?    ?
# 46      male  NaN      0      0      113798       31     ?        S    ?    ?
# 59    female  NaN      0      0       17770  27.7208     ?        C    5    ?
# ...      ...  ...    ...    ...         ...      ...   ...      ...  ...  ...
# 1293    male  NaN      0      0    A/5 2466     8.05     ?        S    ?    ?
# 1297    male  NaN      0      0  A/4. 34244     7.25     ?        S    ?    ?
# 1302    male  NaN      0      0        2647    7.225     ?        C    ?    ?
# 1303    male  NaN      0      0        2627  14.4583     ?        C    ?    ?
# 1305  female  NaN      1      0        2665  14.4542     ?        C    ?    ?
#
#              home.dest  age_float
# 15        New York, NY        NaN
# 37     Los Angeles, CA        NaN
# 40    Philadelphia, PA        NaN
# 46                   ?        NaN
# 59        New York, NY        NaN
# ...                ...        ...
# 1293                 ?        NaN
# 1297                 ?        NaN
# 1302                 ?        NaN
# 1303                 ?        NaN
# 1305                 ?        NaN
#
# [263 rows x 15 columns]

# %%
ages = titanic['age'].dropna()
ages.mean()
# Out:
# 29.8811345124283

# %%
titanic.dropna()
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1301       3         0                             Youseff, Mr. Gerious
# 1304       3         0                             Zabour, Miss. Hileni
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# 0     female  29.0000      0      0   24160  211.3375       B5        S    2
# 1       male   0.9167      1      2  113781    151.55  C22 C26        S   11
# 2     female   2.0000      1      2  113781    151.55  C22 C26        S    ?
# 3       male  30.0000      1      2  113781    151.55  C22 C26        S    ?
# 4     female  25.0000      1      2  113781    151.55  C22 C26        S    ?
# ...      ...      ...    ...    ...     ...       ...      ...      ...  ...
# 1301    male  45.5000      0      0    2628     7.225        ?        C    ?
# 1304  female  14.5000      1      0    2665   14.4542        ?        C    ?
# 1306    male  26.5000      0      0    2656     7.225        ?        C    ?
# 1307    male  27.0000      0      0    2670     7.225        ?        C    ?
# 1308    male  29.0000      0      0  315082     7.875        ?        S    ?
#
#      body                        home.dest  age_float
# 0       ?                     St Louis, MO    29.0000
# 1       ?  Montreal, PQ / Chesterville, ON     0.9167
# 2       ?  Montreal, PQ / Chesterville, ON     2.0000
# 3     135  Montreal, PQ / Chesterville, ON    30.0000
# 4       ?  Montreal, PQ / Chesterville, ON    25.0000
# ...   ...                              ...        ...
# 1301  312                                ?    45.5000
# 1304  328                                ?    14.5000
# 1306  304                                ?    26.5000
# 1307    ?                                ?    27.0000
# 1308    ?                                ?    29.0000
#
# [1046 rows x 15 columns]

# %%
titanic.dropna(subset=['age'])
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1301       3         0                             Youseff, Mr. Gerious
# 1304       3         0                             Zabour, Miss. Hileni
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# 0     female  29.0000      0      0   24160  211.3375       B5        S    2
# 1       male   0.9167      1      2  113781    151.55  C22 C26        S   11
# 2     female   2.0000      1      2  113781    151.55  C22 C26        S    ?
# 3       male  30.0000      1      2  113781    151.55  C22 C26        S    ?
# 4     female  25.0000      1      2  113781    151.55  C22 C26        S    ?
# ...      ...      ...    ...    ...     ...       ...      ...      ...  ...
# 1301    male  45.5000      0      0    2628     7.225        ?        C    ?
# 1304  female  14.5000      1      0    2665   14.4542        ?        C    ?
# 1306    male  26.5000      0      0    2656     7.225        ?        C    ?
# 1307    male  27.0000      0      0    2670     7.225        ?        C    ?
# 1308    male  29.0000      0      0  315082     7.875        ?        S    ?
#
#      body                        home.dest  age_float
# 0       ?                     St Louis, MO    29.0000
# 1       ?  Montreal, PQ / Chesterville, ON     0.9167
# 2       ?  Montreal, PQ / Chesterville, ON     2.0000
# 3     135  Montreal, PQ / Chesterville, ON    30.0000
# 4       ?  Montreal, PQ / Chesterville, ON    25.0000
# ...   ...                              ...        ...
# 1301  312                                ?    45.5000
# 1304  328                                ?    14.5000
# 1306  304                                ?    26.5000
# 1307    ?                                ?    27.0000
# 1308    ?                                ?    29.0000
#
# [1046 rows x 15 columns]

# %%
titanic['boat'].value_counts()
# Out:
# ?          823
# 13          39
# C           38
# 15          37
# 14          33
# 4           31
# 10          29
# 5           27
# 3           26
# 9           25
# 11          25
# 16          23
# 8           23
# 7           23
# D           20
# 6           20
# 12          19
# 2           13
# A           11
# B            9
# 1            5
# 5 7          2
# C D          2
# 13 15        2
# 5 9          1
# 8 10         1
# 13 15 B      1
# 15 16        1
# Name: boat, dtype: int64

# %%
titanic.fillna(0)
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# 0     female  29.0000      0      0   24160  211.3375       B5        S    2
# 1       male   0.9167      1      2  113781    151.55  C22 C26        S   11
# 2     female   2.0000      1      2  113781    151.55  C22 C26        S    ?
# 3       male  30.0000      1      2  113781    151.55  C22 C26        S    ?
# 4     female  25.0000      1      2  113781    151.55  C22 C26        S    ?
# ...      ...      ...    ...    ...     ...       ...      ...      ...  ...
# 1304  female  14.5000      1      0    2665   14.4542        ?        C    ?
# 1305  female   0.0000      1      0    2665   14.4542        ?        C    ?
# 1306    male  26.5000      0      0    2656     7.225        ?        C    ?
# 1307    male  27.0000      0      0    2670     7.225        ?        C    ?
# 1308    male  29.0000      0      0  315082     7.875        ?        S    ?
#
#      body                        home.dest  age_float
# 0       ?                     St Louis, MO    29.0000
# 1       ?  Montreal, PQ / Chesterville, ON     0.9167
# 2       ?  Montreal, PQ / Chesterville, ON     2.0000
# 3     135  Montreal, PQ / Chesterville, ON    30.0000
# 4       ?  Montreal, PQ / Chesterville, ON    25.0000
# ...   ...                              ...        ...
# 1304  328                                ?    14.5000
# 1305    ?                                ?     0.0000
# 1306  304                                ?    26.5000
# 1307    ?                                ?    27.0000
# 1308    ?                                ?    29.0000
#
# [1309 rows x 15 columns]
