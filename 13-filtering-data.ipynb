# %%
import pandas as pd
houses = pd.read_csv('DataAnalysis/data/kc_house_data.csv')
titanic = pd.read_csv('DataAnalysis/data/titanic.csv')
netflix = pd.read_csv('DataAnalysis/data/netflix_titles.csv', sep="|", index_col=0)
bitcoin = pd.read_csv('DataAnalysis/data/coin_Bitcoin.csv')

# %%
df = titanic
df.head()[df.sex == 'female']
# Out:
# /tmp/ipykernel_26264/3267637959.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df.head()[df.sex == 'female']
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#   age  sibsp  parch  ticket      fare    cabin embarked boat body  \
# 0  29      0      0   24160  211.3375       B5        S    2    ?
# 2   2      1      2  113781    151.55  C22 C26        S    ?    ?
# 4  25      1      2  113781    151.55  C22 C26        S    ?    ?
#
#                          home.dest
# 0                     St Louis, MO
# 2  Montreal, PQ / Chesterville, ON
# 4  Montreal, PQ / Chesterville, ON

# %%
df[df.sex == 'female'].survived.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot: >

# %%
df[df.sex == 'male'].survived.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot: >

# %%
titanic['age'] = pd.to_numeric(titanic['age'], errors='coerce')
titanic[titanic.age < 20]
# Out:
#       pclass  survived                                               name  \
# 1          1         1                     Allison, Master. Hudson Trevor
# 2          1         0                       Allison, Miss. Helen Loraine
# 11         1         1  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# 27         1         1            Bishop, Mrs. Dickinson H (Helen Walton)
# 53         1         0                             Carrau, Mr. Jose Pedro
# ...      ...       ...                                                ...
# 1275       3         0                    Vander Planke, Mr. Leo Edmondus
# 1279       3         0               Vestrom, Miss. Hulda Amanda Adolfina
# 1288       3         0                          Wiklund, Mr. Jakob Alfred
# 1300       3         1            Yasbeck, Mrs. Antoni (Selini Alexander)
# 1304       3         0                               Zabour, Miss. Hileni
#
#          sex      age  sibsp  parch    ticket     fare    cabin embarked boat  \
# ...

# %%
titanic[titanic.pclass != 1].pclass.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot: >

# %%
houses[houses.price > 5000000.0]
# Out:
#               id             date      price  bedrooms  bathrooms  \
# 1164  1247600105  20141020T000000  5110800.0         5       5.25
# 1315  7558700030  20150413T000000  5300000.0         6       6.00
# 1448  8907500070  20150413T000000  5350000.0         5       5.00
# 3914  9808700762  20140611T000000  7062500.0         5       4.50
# 4411  2470100110  20140804T000000  5570000.0         5       5.75
# 7252  6762700020  20141013T000000  7700000.0         6       8.00
# 9254  9208900037  20140919T000000  6885000.0         6       7.75
#
#       sqft_living  sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 1164         8010     45517     2.0           1     4  ...     12        5990
# 1315         7390     24829     2.0           1     4  ...     12        5000
# 1448         8000     23985     2.0           0     4  ...     12        6720
# 3914        10040     37325     2.0           1     2  ...     11        7680
# ...

# %%
houses[houses['bedrooms'] >= 10 ]
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 8757   1773100755  20140821T000000   520000.0        11       3.00
# 13314   627300145  20140814T000000  1148000.0        10       5.25
# 15161  5566100170  20141029T000000   650000.0        10       2.00
# 15870  2402100895  20140625T000000   640000.0        33       1.75
# 19254  8812401450  20141229T000000   660000.0        10       3.00
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 8757          3000      4960     2.0           0     0  ...      7
# 13314         4590     10920     1.0           0     2  ...      9
# 15161         3610     11914     2.0           0     0  ...      7
# 15870         1620      6000     1.0           0     0  ...      7
# 19254         2920      3745     2.0           0     0  ...      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 8757         2400            600      1918          1999    98106  47.5560
# ...

# %%
houses[houses['sqft_living'] <= 1000]
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 46     8945200830  20150325T000000  210490.0         3       1.00
# 68     1274500060  20140825T000000  204000.0         3       1.00
# 84     1133000671  20140602T000000  315000.0         3       1.00
# 117    4060000240  20140623T000000  205425.0         2       1.00
# ...           ...              ...       ...       ...        ...
# 21489  6021503707  20150120T000000  352500.0         2       2.50
# 21538  1865400076  20140509T000000  324000.0         3       2.25
# 21569  6021503705  20141015T000000  329000.0         2       2.50
# 21578   567000385  20140623T000000  362500.0         2       1.50
# 21583  2025049203  20140610T000000  399950.0         2       1.00
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 2              770     10000     1.0           0     0  ...      6
# ...

# %%
houses[houses['bedrooms'].between(5, 7)].bedrooms.value_counts()
# Out:
# 5    1601
# 6     272
# 7      38
# Name: bedrooms, dtype: int64

# %%
houses[houses['grade'].between(11, 13)].grade.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot: >

# %%
houses[houses['price'] > 6000000.0]
# Out:
#               id             date      price  bedrooms  bathrooms  \
# 3914  9808700762  20140611T000000  7062500.0         5       4.50
# 7252  6762700020  20141013T000000  7700000.0         6       8.00
# 9254  9208900037  20140919T000000  6885000.0         6       7.75
#
#       sqft_living  sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 3914        10040     37325     2.0           1     2  ...     11        7680
# 7252        12050     27600     2.5           0     3  ...     13        8570
# 9254         9890     31374     2.0           0     4  ...     13        8860
#
#       sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 3914           2360      1940          2001    98004  47.6500 -122.214
# 7252           3480      1910          1987    98102  47.6298 -122.323
# 9254           1030      2001             0    98039  47.6305 -122.240
#
#       sqft_living15  sqft_lot15
# 3914           3930       25449
# ...

# %%
countries = ['India', 'Japan', 'South Korea']
netflix[netflix['country'].isin(countries)]['country'].value_counts()
# Out:
# India          972
# Japan          245
# South Korea    199
# Name: country, dtype: int64

# %%
tv = ['TV-MA', 'R']
netflix[netflix['rating'].isin(tv)]['rating'].value_counts()
# Out:
# TV-MA    3207
# R         799
# Name: rating, dtype: int64

# %%
women = titanic['sex'] == 'female'
fclass = titanic['pclass'] == 1
fclass_women = woman & fclass
titanic[fclass_women]['age'].value_counts().sort_index().median()
# Out:
# 2.0

# %%
waterfront = houses['waterfront'] == 1
good_grade = houses['grade'] >= 7
cheap = houses['price'] < 600000.0
houses[waterfront & good_grade & cheap].sort_values(by="grade")
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 4912    121029034  20140624T000000  549000.0         2       1.00
# 8277    221029019  20150428T000000  400000.0         3       2.50
# 11556  2013802030  20140911T000000  357000.0         3       2.00
# 13525  2013802060  20140927T000000  500000.0         2       1.00
# 14827  2423029009  20140617T000000  465000.0         2       2.00
# 15330  9536600010  20141223T000000  520000.0         4       0.75
# 8156   1121039059  20140522T000000  503000.0         2       1.75
# 8450    121039042  20150313T000000  425000.0         3       2.75
# 17474  6329000185  20150329T000000  540000.0         3       2.50
# 18848  7631800110  20140918T000000  380000.0         3       2.50
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 4912          2034     13392     1.0           1     4  ...      7
# 8277          2090     32718     2.0           1     4  ...      7
# ...

# %%
houses[(houses['price'] < 600000.0) & (houses['waterfront'] == 1) & (houses['grade'] > 7)]
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 8156   1121039059  20140522T000000  503000.0         2       1.75
# 8450    121039042  20150313T000000  425000.0         3       2.75
# 17474  6329000185  20150329T000000  540000.0         3       2.50
# 18848  7631800110  20140918T000000  380000.0         3       2.50
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 8156          2860     59612     1.0           1     4  ...      8
# 8450          3610    107386     1.5           1     3  ...      8
# 17474         2600     23361     1.5           1     4  ...      8
# 18848         1980     17342     2.0           1     4  ...     10
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 8156         1510           1350      1948          2003    98023  47.3276
# 8450         3130            480      1918          1962    98023  47.3351
# ...

# %%
houses[(houses['view'] == 4) & (houses['grade'] >= 9) & (houses['floors'] > 1)]
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 312    1860600135  20140502T000000  2384000.0         5       2.50
# 540     622049114  20150218T000000  2125000.0         3       2.50
# 757    9273200140  20150121T000000  1310000.0         2       2.25
# 1164   1247600105  20141020T000000  5110800.0         5       5.25
# 1315   7558700030  20150413T000000  5300000.0         6       6.00
# ...           ...              ...        ...       ...        ...
# 20767  8043700105  20150417T000000  2300000.0         4       4.00
# 20923  7852070210  20140527T000000  1149000.0         4       3.00
# 21050  2424059170  20150219T000000   900000.0         5       6.00
# 21201   518500460  20141008T000000  2230000.0         3       3.50
# 21576  9253900271  20150107T000000  3567000.0         5       4.50
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 312           3650      9050     2.0           0     4  ...     10
# ...

# %%
houses[(houses['yr_built'] > 2012) | (houses['yr_renovated'] > 2012)]
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 42     7203220400  20140707T000000  861990.0         5       2.75
# 63     9528102996  20141207T000000  549000.0         3       1.75
# 133    8929000270  20140512T000000  453246.0         3       2.50
# 139    2767603505  20140507T000000  519950.0         3       2.25
# 158    8029200135  20141113T000000  247000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21598  8956200760  20141013T000000  541800.0         4       2.50
# 21602   844000965  20140626T000000  224000.0         3       1.75
# 21604  9834201367  20150126T000000  429000.0         3       2.00
# 21605  3448900210  20141014T000000  610685.0         4       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 42            3595      5639     2.0           0     0  ...      9
# ...

# %%
netflix
# Out:
# <AxesSubplot: >

# %%
woman = titanic['sex'] == 'female'
titanic[~woman]
# Out:
#       pclass  survived                                  name   sex     age  \
# 1          1         1        Allison, Master. Hudson Trevor  male  0.9167
# 3          1         0  Allison, Mr. Hudson Joshua Creighton  male      30
# 5          1         1                   Anderson, Mr. Harry  male      48
# 7          1         0                Andrews, Mr. Thomas Jr  male      39
# 9          1         0               Artagaveytia, Mr. Ramon  male      71
# ...      ...       ...                                   ...   ...     ...
# 1302       3         0                     Yousif, Mr. Wazli  male       ?
# 1303       3         0                 Yousseff, Mr. Gerious  male       ?
# 1306       3         0             Zakarian, Mr. Mapriededer  male    26.5
# 1307       3         0                   Zakarian, Mr. Ortin  male      27
# 1308       3         0                    Zimmerman, Mr. Leo  male      29
#
#       sibsp  parch    ticket     fare    cabin embarked boat body  \
# ...

# %%
netflix[(netflix['director'].isna()) & (netflix['cast'].isna()) & (netflix['country'].isna())]
# Out:
#      show_id     type                                      title director  \
# 3         s4  TV Show                      Jailbirds New Orleans      NaN
# 10       s11  TV Show        Vendetta: Truth, Lies and The Mafia      NaN
# 14       s15  TV Show            Crime Stories: India Detectives      NaN
# 74       s75  TV Show  The World's Most Amazing Vacation Rentals      NaN
# 123     s124  TV Show                                  Luv Kushh      NaN
# ...      ...      ...                                        ...      ...
# 7812   s7813  TV Show                           Queens of Comedy      NaN
# 8109   s8110  TV Show                                 Strongland      NaN
# 8199   s8200  TV Show                               The Bachelor      NaN
# 8609   s8610  TV Show                                     Towies      NaN
# 8803   s8804  TV Show                                Zombie Dumb      NaN
#
#      cast country          date_added  release_year rating   duration  \
# ...

# %%
titanic[titanic['sex'] == 'male'].survived.value_counts().plot(kind='pie')
# Out:
# <AxesSubplot: ylabel='survived'>

# %%
titanic[titanic['sex'] == 'female'].survived.value_counts().plot(kind='pie')
# Out:
# <AxesSubplot: ylabel='survived'>

# %%
houses[houses['price'] > 3000000.0].zipcode.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot: >
