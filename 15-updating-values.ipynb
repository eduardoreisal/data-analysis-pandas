# %%
import pandas as pd
houses = pd.read_csv('DataAnalysis/data/kc_house_data.csv')
titanic = pd.read_csv('DataAnalysis/data/titanic.csv')
netflix = pd.read_csv('DataAnalysis/data/netflix_titles.csv', sep="|", index_col=0)
bitcoin = pd.read_csv('DataAnalysis/data/coin_Bitcoin.csv')
countries = pd.read_csv('DataAnalysis/data/world-happiness-report-2021.csv')

# %%
mapper = {"Regional indicator": "regional_indicator", "Ladder score": "ladder_Score"}
countries.rename(columns=mapper)
# Out:
#     Country name  regional_indicator  ladder_Score  \
# 0        Finland      Western Europe         7.842
# 1        Denmark      Western Europe         7.620
# 2    Switzerland      Western Europe         7.571
# 3        Iceland      Western Europe         7.554
# 4    Netherlands      Western Europe         7.464
# ..           ...                 ...           ...
# 144      Lesotho  Sub-Saharan Africa         3.512
# 145     Botswana  Sub-Saharan Africa         3.467
# 146       Rwanda  Sub-Saharan Africa         3.415
# 147     Zimbabwe  Sub-Saharan Africa         3.145
# 148  Afghanistan          South Asia         2.523
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                             0.032         7.904         7.780
# 1                             0.035         7.687         7.552
# 2                             0.036         7.643         7.500
# 3                             0.059         7.670         7.438
# ...

# %%
mapper2 = {"Finland": "finland", "Denmark": "denmark"}
countries.rename(index=mapper2)
# Out:
#               Regional indicator  Ladder score  \
# Country name
# finland           Western Europe         7.842
# denmark           Western Europe         7.620
# Switzerland       Western Europe         7.571
# Iceland           Western Europe         7.554
# Netherlands       Western Europe         7.464
# ...                          ...           ...
# Lesotho       Sub-Saharan Africa         3.512
# Botswana      Sub-Saharan Africa         3.467
# Rwanda        Sub-Saharan Africa         3.415
# Zimbabwe      Sub-Saharan Africa         3.145
# Afghanistan           South Asia         2.523
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# finland                                0.032         7.904         7.780
# denmark                                0.035         7.687         7.552
# Switzerland                            0.036         7.643         7.500
# ...

# %%
titanic['sex'].replace(['male', 'female'], ['M', 'F'], inplace=True)
titanic['age'].replace('1.0000', 'IDK', inplace=True)
titanic
# Out:
#       pclass  survived                                             name sex  \
# 0          1         1                    Allen, Miss. Elisabeth Walton   F
# 1          1         1                   Allison, Master. Hudson Trevor   M
# 2          1         0                     Allison, Miss. Helen Loraine   F
# 3          1         0             Allison, Mr. Hudson Joshua Creighton   M
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)   F
# ...      ...       ...                                              ...  ..
# 1304       3         0                             Zabour, Miss. Hileni   F
# 1305       3         0                            Zabour, Miss. Thamine   F
# 1306       3         0                        Zakarian, Mr. Mapriededer   M
# 1307       3         0                              Zakarian, Mr. Ortin   M
# 1308       3         0                               Zimmerman, Mr. Leo   M
#
# ...

# %%
titanic.replace(['IDK'], [None])
titanic
# Out:
#       pclass  survived                                             name sex  \
# 0          1         1                    Allen, Miss. Elisabeth Walton   F
# 1          1         1                   Allison, Master. Hudson Trevor   M
# 2          1         0                     Allison, Miss. Helen Loraine   F
# 3          1         0             Allison, Mr. Hudson Joshua Creighton   M
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)   F
# ...      ...       ...                                              ...  ..
# 1304       3         0                             Zabour, Miss. Hileni   F
# 1305       3         0                            Zabour, Miss. Thamine   F
# 1306       3         0                        Zakarian, Mr. Mapriededer   M
# 1307       3         0                              Zakarian, Mr. Ortin   M
# 1308       3         0                               Zimmerman, Mr. Leo   M
#
# ...

# %%
titanic.age.replace(['IDK'], [None], inplace=True)

# %%
titanic.age.value_counts(dropna=False)
# Out:
# None      263
# 24         47
# 22         43
# 21         41
# 30         40
#          ...
# 66          1
# 0.6667      1
# 76          1
# 67          1
# 26.5        1
# Name: age, Length: 99, dtype: int64

# %%
countries.sort_index().loc['Brazil':'Cambodia']
# Out:
#                        Regional indicator  Ladder score  \
# Country name
# Brazil        Latin America and Caribbean         6.330
# Bulgaria       Central and Eastern Europe         5.266
# Burkina Faso           Sub-Saharan Africa         4.834
# Burundi                Sub-Saharan Africa         3.775
# Cambodia                   Southeast Asia         4.830
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Brazil                                 0.043         6.415         6.245
# Bulgaria                               0.054         5.371         5.160
# Burkina Faso                           0.081         4.993         4.675
# Burundi                                0.107         3.985         3.565
# Cambodia                               0.067         4.963         4.698
#
#               Logged GDP per capita  Social support  Healthy life expectancy  \
# Country name
# ...

# %%
countries.loc['Brazil', ['Ladder score', 'Healthy life expectancy']]
# Out:
# Ladder score                 6.33
# Healthy life expectancy    66.601
# Name: Brazil, dtype: object

# %%
celooking_countries = ['Brazil', 'Canada', 'Ukraine', 'Russia', 'China', 'Japan', 'Argentina', 'Venezuela']
metrics = ['Ladder score', 'Social support', 'Healthy life expectancy']
countries.loc[looking_countries, metrics].sort_values('Ladder score')
# Out:
#               Ladder score  Social support  Healthy life expectancy
# Country name
# Ukraine              4.875           0.888                   64.902
# Venezuela            4.892           0.861                   66.700
# China                5.339           0.811                   69.593
# Russia               5.477           0.903                   64.703
# Argentina            5.929           0.898                   69.000
# Japan                5.940           0.884                   75.100
# Brazil               6.330           0.882                   66.601
# Canada               7.103           0.926                   73.800

# %%
countries.loc[['Denmark', 'Sweden', 'Norway'], ['Regional indicator']] = 'Scandinavia'

# %%
countries.head(10)
# Out:
#                  Regional indicator  Ladder score  \
# Country name
# Finland              Western Europe         7.842
# Denmark                 Scandinavia         7.620
# Switzerland          Western Europe         7.571
# Iceland              Western Europe         7.554
# Netherlands          Western Europe         7.464
# Norway                  Scandinavia         7.392
# Sweden                  Scandinavia         7.363
# Luxembourg           Western Europe         7.324
# New Zealand   North America and ANZ         7.277
# Austria              Western Europe         7.268
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Finland                                0.032         7.904         7.780
# Denmark                                0.035         7.687         7.552
# Switzerland                            0.036         7.643         7.500
# Iceland                                0.059         7.670         7.438
# ...

# %%
countries.loc[['Finland'], ['Regional indicator', 'isCold']] = ['Finland', 'Yes!!']
countries.loc['Finland']
# Out:
# Regional indicator                            Finland
# Ladder score                                    7.842
# Standard error of ladder score                  0.032
# upperwhisker                                    7.904
# lowerwhisker                                     7.78
# Logged GDP per capita                          10.775
# Social support                                  0.954
# Healthy life expectancy                          72.0
# Freedom to make life choices                    0.949
# Generosity                                     -0.098
# Perceptions of corruption                       0.186
# Ladder score in Dystopia                         2.43
# Explained by: Log GDP per capita                1.446
# Explained by: Social support                    1.106
# Explained by: Healthy life expectancy           0.741
# Explained by: Freedom to make life choices      0.691
# Explained by: Generosity                        0.124
# ...

# %%
many_bedrooms = houses['bedrooms'] >= 10
houses.loc[many_bedrooms, ['bedrooms']] = 'TOO MANY!'
houses.loc[many_bedrooms]
# Out:
#                id             date      price   bedrooms  bathrooms  \
# 8757   1773100755  20140821T000000   520000.0  TOO MANY!       3.00
# 13314   627300145  20140814T000000  1148000.0  TOO MANY!       5.25
# 15161  5566100170  20141029T000000   650000.0  TOO MANY!       2.00
# 15870  2402100895  20140625T000000   640000.0  TOO MANY!       1.75
# 19254  8812401450  20141229T000000   660000.0  TOO MANY!       3.00
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 8757          3000      4960     2.0           0     0  ...      7
# 13314         4590     10920     1.0           0     2  ...      9
# 15161         3610     11914     2.0           0     0  ...      7
# 15870         1620      6000     1.0           0     0  ...      7
# 19254         2920      3745     2.0           0     0  ...      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# ...

# %%
high_grade = (houses['grade'] > 12) & (houses['view'] >= 3)
houses.loc[high_grade].sort_values('price')
# Out:
#                id             date      price bedrooms  bathrooms  \
# 14556  2303900035  20140611T000000  2888000.0        5       6.25
# 10373  3303850390  20141212T000000  2983000.0        5       5.50
# 19017  2303900100  20140911T000000  3800000.0        3       4.25
# 9254   9208900037  20140919T000000  6885000.0        6       7.75
# 7252   6762700020  20141013T000000  7700000.0        6       8.00
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 14556         8670     64033     2.0           0     4  ...     13
# 10373         7400     18898     2.0           0     3  ...     13
# 19017         5510     35000     2.0           0     4  ...     13
# 9254          9890     31374     2.0           0     4  ...     13
# 7252         12050     27600     2.5           0     3  ...     13
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 14556        6120           2550      1965          2003    98177  47.7295
# ...

# %%
houses.loc[high_grade, ['luxury_level']] = 'ultra'
ultra = houses['luxury_level'] == 'ultra'
houses.loc[ultra]
# Out:
#                id             date      price bedrooms  bathrooms  \
# 7252   6762700020  20141013T000000  7700000.0        6       8.00
# 9254   9208900037  20140919T000000  6885000.0        6       7.75
# 10373  3303850390  20141212T000000  2983000.0        5       5.50
# 14556  2303900035  20140611T000000  2888000.0        5       6.25
# 19017  2303900100  20140911T000000  3800000.0        3       4.25
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  sqft_above  \
# 7252         12050     27600     2.5           0     3  ...        8570
# 9254          9890     31374     2.0           0     4  ...        8860
# 10373         7400     18898     2.0           0     3  ...        6290
# 14556         8670     64033     2.0           0     4  ...        6120
# 19017         5510     35000     2.0           0     4  ...        4910
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...
